# %%
# List
tasks = ["load_data", "clean_data"]

# Add element
tasks.append("train_model")
print(tasks)

# Remove element
tasks.remove("clean_data")
print(tasks)
# Out:
# ['load_data', 'clean_data', 'train_model']
# ['load_data', 'train_model']

# %%
# Set
users = {"alice", "bob", "alice"}
print(users)

# Add element
users.add("charlie")
print(users)

# Membership test
print("bob" in users)
# Out:
# {'bob', 'alice'}
# {'bob', 'alice', 'charlie'}
# True

# %%
# Dict
model_scores = {
    "model_A": 0.82,
    "model_B": 0.78
}

# Update value
model_scores["model_B"] = 0.81

# Add new key
model_scores["model_C"] = 0.85

print(model_scores)
# Out:
# {'model_A': 0.82, 'model_B': 0.81, 'model_C': 0.85}

# %%
# Tuple

point = (10, 20)

# Read works
print(point[0])

# Modification fails
point[0] = 5
# Out:
# 10
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 9
#       6 print(point[0])
#       8 # Modification fails
# ----> 9 point[0] = 5
#
# TypeError: 'tuple' object does not support item assignment
